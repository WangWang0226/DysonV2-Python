# %%
import sys
import math
from datetime import datetime, timezone
from dyson_pool import DysonPool
from time_utils import TimeManager
import pandas as pd

# %%
# Initial pool state
init_eth = 100
init_usdc = 200000
price = init_usdc / init_eth

deposit_dt = datetime(2025, 4, 1, 16, 0, tzinfo=timezone.utc)
withdraw_dt = datetime(2025, 4, 3, 0, 0, tzinfo=timezone.utc)
    
def get_new_pool():
    tm = TimeManager()
    pool = DysonPool(init_eth, init_usdc, basis=0.5, w_factor=1, tm=tm)
    tm.setCurrentTime(deposit_dt)
    return pool, tm

# %% [markdown]
# ## Test Forward Deposit & Withdraw

# %%
# Forward deposit
def process_deposit_withdraw(in0, in1, lock_days):
    pool, tm = get_new_pool()
    deposit_result = pool.deposit(in0, in1, lock_days)
    nid, _, _, _, _, _, _, _, _, _ = deposit_result

    print("deposit info:")
    df = pd.DataFrame([deposit_result], columns=['nid', 'note0', 'note1', 'note0_with_prem', 'note1_with_prem', 'prem_ratio', 'due', 'duration_sec', 'q_old', 'q_new'])
    display(df)

    # Withdraw due
    tm.setCurrentTime(withdraw_dt)
    withdraw0, withdraw1 = pool.withdraw(withdraw_dt, nid)

    print("withdraw info:")
    withdraw_df = pd.DataFrame([{'withdraw0': withdraw0, 'withdraw1': withdraw1}])
    display(withdraw_df)

# %% [markdown]
# ### Test Single Side Deposit

# %%
in0, in1, lock_days = 10, 0, 1
process_deposit_withdraw(in0, in1, lock_days)
# Out:
# deposit info:
#    nid  note0         note1  note0_with_prem  note1_with_prem  prem_ratio  \
# 0    0   10.0  19058.429278        10.118022     19283.361032    0.011802
#
#      due  duration_sec  q_old       q_new
# 0  20181        115200    0.0  218.279805
# withdraw info:
#    withdraw0    withdraw1
# 0    7.58879  4820.319489

# %% [markdown]
# ### Test Double Side Deposit

# %%
in0, in1, lock_days = 1, 2000, 1
process_deposit_withdraw(in0, in1, lock_days)
# Out:
# deposit info:
#    nid  note0   note1  note0_with_prem  note1_with_prem  prem_ratio    due  \
# 0    0    2.0  4000.0         2.024056      4048.111671    0.012028  20181
#
#    duration_sec  q_old     q_new
# 0        115200    0.0  44.72136
# withdraw info:
#    withdraw0    withdraw1
# 0   1.012028  2024.055836

# %% [markdown]
# # Test Withdraw After Rebalance

# %%
def rebalance(price: float, x: float, y: float) -> tuple[float, float]:
    """Rebalance pool to 50/50 asset ratio based on current price, and update internal state."""
    eth_val = x * price
    total_val = eth_val + y
    target = total_val / 2

    if eth_val > target:
        diff = eth_val - target
        new_x = x - diff / price
        new_y = y + diff
    elif y > target:
        diff = y - target
        new_x = x + diff / price
        new_y = y - diff
    else:
        # 若已經是 50/50 就不變
        new_x, new_y = x, y

    return new_x, new_y

# %%
# Forward deposit
pool, tm = get_new_pool()
in0, in1, lock_days = 10, 0, 1
deposit_result = pool.deposit(in0, in1, lock_days)
nid, _, _, _, _, _, _, _, _, _ = deposit_result

new_x, new_y = rebalance(price, pool.x, pool.y)
pool.swap(new_x, new_y)

# Withdraw due
tm.setCurrentTime(withdraw_dt)
withdraw0, withdraw1 = pool.withdraw(withdraw_dt, nid)

print("withdraw info:")
withdraw_df = pd.DataFrame([{'withdraw0': withdraw0, 'withdraw1': withdraw1}])
display(withdraw_df)
# Out:
# withdraw info:
#    withdraw0     withdraw1
# 0   2.465279  14584.926809

# %% [markdown]
# # Test Deposit at Midnight

# %%
# Forward deposit
pool, tm = get_new_pool()
# 2025-04-02 00:00:00
tm.setCurrentTime(datetime(2025, 4, 2, 0, 0, tzinfo=timezone.utc))
in0, in1, lock_days = 10, 0, 1
deposit_result = pool.deposit(in0, in1, lock_days)

print("deposit info:")
df = pd.DataFrame([deposit_result], columns=['nid', 'note0', 'note1', 'note0_with_prem', 'note1_with_prem', 'prem_ratio', 'due', 'duration_sec', 'q_old', 'q_new'])
display(df)
# Out:
# deposit info:
#    nid  note0         note1  note0_with_prem  note1_with_prem  prem_ratio  \
# 0    0   10.0  19058.429278         10.10221     19253.225891    0.010221
#
#      due  duration_sec  q_old       q_new
# 0  20181         86400    0.0  218.279805

# %% [markdown]
# # Test Multiple Deposits

# %%
# Forward deposit
pool, tm = get_new_pool()
in0, in1, lock_days = 10, 0, 1
deposit_result = pool.deposit(in0, in1, lock_days)

in0, in1 = 1, 2000
deposit_result2 = pool.deposit(in0, in1, lock_days)

print("deposit info:")
df = pd.DataFrame([deposit_result, deposit_result2], columns=['nid', 'note0', 'note1', 'note0_with_prem', 'note1_with_prem', 'prem_ratio', 'due', 'duration_sec', 'q_old', 'q_new'])
display(df)

# Withdraw due
tm.setCurrentTime(withdraw_dt)
nid0 = df.loc[0, "nid"]
nid1 = df.loc[1, "nid"]

withdraw0, withdraw1 = pool.withdraw(withdraw_dt, nid1)

print("nid1 withdraw info:")
withdraw_df = pd.DataFrame([{"withdraw0": withdraw0, "withdraw1": withdraw1}])
display(withdraw_df)

withdraw0, withdraw1 = pool.withdraw(withdraw_dt, nid0)
print("nid0 withdraw info:")
withdraw_df = pd.DataFrame([{"withdraw0": withdraw0, "withdraw1": withdraw1}])
display(withdraw_df)
# Out:
# deposit info:
#    nid      note0         note1  note0_with_prem  note1_with_prem  prem_ratio  \
# 0    0  10.000000  19058.429278        10.118022     19283.361032    0.011802
# 1    1   2.099955   3818.181818         2.124043      3861.979250    0.011471
#
#      due  duration_sec       q_old       q_new
# 0  20181        115200    0.000000  218.279805
# 1  20181        115200  218.279805  263.051475
# nid1 withdraw info:
#    withdraw0    withdraw1
# 0   1.013213  2019.735153
# nid0 withdraw info:
#    withdraw0    withdraw1
# 0   7.587361  4823.042415

# %% [markdown]
# ## Test Reverse Deposit And Exercise Option

# %%
def perform_reverse_deposit_and_exercise(pool, m, n, lock_days, option_type):
    deposit_result = pool.reverse_deposit(m, n, lock_days)

    nid = deposit_result[0]  # assuming nid is at index 0
    out0, out1 = pool.exercise_option(nid, option_type)

    print(f"Exercised {option_type} option")
    print(
        f"Swap in: {out1:.6f}, Swap out: {out0:.6f}"
        if option_type == "call"
        else f"Swap in: {out0:.6f}, Swap out: {out1:.6f}"
    )

    return deposit_result


# 初始化
in0, in1, lock_days = 1, 2000, 1
pool, tm = get_new_pool()
pool.deposit(in0, in1, lock_days)

# Reverse deposit parameters
m, n = 1, 200

# 收集所有 reverse deposit 結果
reverse_results = []

# 第一次 reverse deposit 並執行 call option
reverse_results.append(
    perform_reverse_deposit_and_exercise(pool, m, n, lock_days, "call")
)

# 第二次 reverse deposit 並執行 put option
reverse_results.append(
    perform_reverse_deposit_and_exercise(pool, m, n, lock_days, "put")
)

# 整合成單一 DataFrame
columns = [
    "nid",
    "m",
    "n",
    "strike",
    "delta_x",
    "delta_y",
    "exercise_call",
    "exercise_put",
    "prem_ratio",
    "due",
    "duration_sec",
    "q_old",
    "q_new",
]
reverse_df = pd.DataFrame(reverse_results, columns=columns)
print("All Reverse Deposit Info:")
display(reverse_df)
# Out:
# Exercised call option
# Swap in: 200.000000, Swap out: 0.099108
# Exercised put option
# Swap in: 1.000000, Swap out: 2059.204315
# All Reverse Deposit Info:
#    nid  m    n       strike  delta_x      delta_y               exercise_call  \
# 0    1  1  200  2018.000000 -0.89853  1866.090647  (200, 0.09910802775024777)
# 1    2  1  200  2059.204315 -0.90056  1908.279117  (200, 0.09712489361400463)
#
#             exercise_put  prem_ratio    due  duration_sec     q_old      q_new
# 0            (1, 2018.0)    0.023831  20181        115200  44.72136  20.079534
# 1  (1, 2059.20431475419)    0.023832  20181        115200  44.72136  19.874891
